# %%
import matplotlib.pyplot as plt

# Data
in_plane_temperatures = [25, 50, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350]
out_of_plane_temperatures = [5, 10, 50, 180, 200, 210, 220, 230, 240, 250, 260, 270, 287, 295, 310, 325, 350]
in_plane_resonance_diff = [0.19,0.23,0.28,0.33,0.37,0.44,0.48,0.55,0.61,0.65,0.62,0.55,0.48]
out_of_plane_resonance_diff = [0.02,0.01,0.02,0.4,0.27,0.14,-0.25,0.01,-0.11,-0.53,-1.00,-0.88,-0.86,-0.84,-0.78,-0.72,-0.59]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(in_plane_temperatures, in_plane_resonance_diff, marker='o', label='In-Plane Resonance Difference', linestyle='-')
plt.plot(out_of_plane_temperatures, out_of_plane_resonance_diff, marker='s', label='Out-of-Plane Resonance Difference', linestyle='--')

# Labels and title
plt.xlabel("Temperature (K)", fontsize=12)
plt.ylabel("Resonance Difference", fontsize=12)
#plt.title("Resonance Differences vs Temperature", fontsize=14)
plt.legend()
#plt.grid(True, linestyle='--', alpha=0.6)

# Annotations
ax = plt.gca()
ax.annotate(r'$YMn_6Sn_6$', ha='left', xy=(0.9, 0.97), weight='bold', xycoords='axes fraction', fontsize=10, color='black')
ax.annotate(r'$\nu=120\ GHz$', ha='left', xy=(0.9, 0.9), xycoords='axes fraction', fontsize=10, color='black')
#ax.annotate(r'$B_\perp$', ha='left', xy=(0.9, 0.86), xycoords='axes fraction', fontsize=22)
#ax.annotate(r'$B_\parallel$', ha='left', xy=(0.9, 0.87), xycoords='axes fraction', fontsize=22)


# Display plot
plt.tight_layout()
plt.savefig("C:\\Users\\lovia\\Desktop\\YMnSn_120GHz_Resonance difference.png", dpi=200, bbox_inches='tight')
plt.show()
