# %%
import matplotlib.pyplot as plt

# Data
in_plane_temperatures = [100, 112.5, 125, 130, 140, 150, 160, 170, 180, 200, 240, 288]
out_of_plane_temperatures = [5, 10, 20, 30, 40, 60, 80, 100, 125, 150, 200, 250, 290]
in_plane_resonance_diff = [1.14, 1.17, 1.16, 1.16, 1.15, 1.13, 1.12, 1.10, 1.08, 1.05, 0.98, 0.88]
out_of_plane_resonance_diff = [-1.22, -1.19, -1.21, -1.24, -1.27, -1.34, -1.9, -1.89, -1.80, -1.71, -1.53, -1.25, -1.13]

# Plotting
plt.figure(figsize=(10, 6))

plt.plot(in_plane_temperatures, in_plane_resonance_diff, marker='o', label='In-Plane Resonance Difference', linestyle='-')
plt.plot(out_of_plane_temperatures, out_of_plane_resonance_diff, marker='s', label='Out-of-Plane Resonance Difference', linestyle='--')

# Labels and title
plt.xlabel("Temperature (K)", fontsize=12)
plt.ylabel("Resonance Difference", fontsize=12)
#plt.title("Resonance Differences vs Temperature", fontsize=14)
plt.legend()
#plt.grid(True, linestyle='--', alpha=0.6)

# Annotations
ax = plt.gca()
ax.annotate(r'$YMn_6Sn_6$', ha='left', xy=(0.9, 0.97), weight='bold', xycoords='axes fraction', fontsize=10, color='black')
ax.annotate(r'$\nu=240\ GHz$', ha='left', xy=(0.9, 0.9), xycoords='axes fraction', fontsize=10, color='black')
#ax.annotate(r'$B_\perp$', ha='left', xy=(0.9, 0.86), xycoords='axes fraction', fontsize=22)
#ax.annotate(r'$B_\parallel$', ha='left', xy=(0.9, 0.87), xycoords='axes fraction', fontsize=22)

# Display plot
plt.tight_layout()
plt.savefig("C:\\Users\\lovia\\Desktop\\YMnSn_240GHz_Resonance difference.png", dpi=200, bbox_inches='tight')
plt.show()
